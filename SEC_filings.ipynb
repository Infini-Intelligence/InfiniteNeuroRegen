# %%
# !pip install openai beautifulsoup4 pandas requests

# %%
import os
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup
from collections import defaultdict
import html
import unicodedata
import json
from openai import AzureOpenAI
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ========== CONFIG ==========
CIK = "0001355790"  # ISCO
FORM_TYPES = ["8-K", "10-K", "10-Q"]
HEADERS = {"User-Agent": "boyangzhu03@gmail.com"}
BASE_URL = "https://www.sec.gov"

# Save to Drive
DATA_PATH = "/content/drive/MyDrive/SEC"
os.makedirs(DATA_PATH, exist_ok=True)

# ========== Azure OpenAI Credentials ==========
os.environ["AZURE_OPENAI_API_VERSION"] = "2024-12-01-preview"
os.environ["AZURE_OPENAI_ENDPOINT"] = "https://extendmeopenaieastus2.openai.azure.com"
os.environ["AZURE_OPENAI_API_KEY"] = "Your.Key"
AZURE_DEPLOYMENT_NAME = "o4-mini"

client = AzureOpenAI(
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    api_version=os.environ["AZURE_OPENAI_API_VERSION"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"]
)

# %%
def fetch_filing_urls(cik):
    try:
        index_url = f"https://data.sec.gov/submissions/CIK{cik}.json"
        response = requests.get(index_url, headers=HEADERS)
        response.raise_for_status()
        data = response.json()["filings"]["recent"]

        urls = []
        for i in range(len(data["form"])):
            if data["form"][i] in FORM_TYPES:
                accession = data["accessionNumber"][i].replace("-", "")
                primary_doc = data["primaryDocument"][i]
                if accession and primary_doc:
                    url = f"{BASE_URL}/Archives/edgar/data/{int(cik)}/{accession}/{primary_doc}"
                    urls.append((data["form"][i], data["filingDate"][i], url))
        return urls
    except Exception as e:
        print(f"[ERROR] Fetching filings: {e}")
        return []

def clean_text(text):
    text = html.unescape(text)
    text = unicodedata.normalize("NFKD", text)
    return re.sub(r"[\x80-\xFF]+", "", text)

# %%
def extract_events_llm(content, max_chars=12000):
    try:
        # Truncate content if too long to avoid timeouts
        if len(content) > max_chars:
            content = content[:max_chars]

        prompt = f"""You are an expert in financial and biotech disclosures. Read the following SEC filing content.

              Extract a list of distinct events (clinical, corporate, regulatory, or IP-related) mentioned in the text.
              For each event, return:
              - A short description (1–2 sentences).
              - A subtype: one of "clinical", "corporate", "regulatory", or "ip".

              Format your answer as JSON:
              [
                {{
                  "description": "...",
                  "subtype": "..."
                }},
                ...
              ]

              Filing content:
              \"\"\"
              {content}
              \"\"\"
              """

        response = client.chat.completions.create(
            model=AZURE_DEPLOYMENT_NAME,
            messages=[
                {"role": "system", "content": "You extract structured events from SEC filings."},
                {"role": "user", "content": prompt}
            ],
            max_completion_tokens=1500  # Slightly reduced for speed
        )

        reply = response.choices[0].message.content.strip()

        # Try parsing as JSON
        try:
            return json.loads(reply)
        except json.JSONDecodeError:
            print("[LLM ERROR] JSON parsing failed. Skipping this result.")
            return []

    except Exception as e:
        print(f"[LLM ERROR] Failed to extract events: {e}")
        return []

# %%
def main():
    filing_urls = fetch_filing_urls(CIK)
    print(f"[INFO] Found {len(filing_urls)} filings")

    all_events = []
    for form_type, filing_date, url in filing_urls:
        print(f"[INFO] Parsing {form_type} from {filing_date}")
        try:
            response = requests.get(url, headers=HEADERS, timeout=10)
            soup = BeautifulSoup(response.text, "html.parser")
            content = clean_text(soup.get_text(" ", strip=True))
            events = extract_events_llm(content)

            if not events:
                print(f"[INFO] No valid events extracted from {filing_date}, skipping.")
                continue  # Skip to next filing

            for e in events:
                all_events.append({
                    "timestamp": filing_date,
                    "form_type": form_type,
                    "event_type": "sec_disclosure",
                    "event_subtype": e.get("subtype", "unknown"),
                    "description": e.get("description", ""),
                    "source_url": url,
                    "confidence": 0.9
                })

        except Exception as e:
            print(f"[ERROR] Parsing filing: {e}")

    df = pd.DataFrame(all_events)
    output_path = os.path.join(DATA_PATH, "isco_events_llm_V2.csv")
    df.to_csv(output_path, index=False)
    print(f"\n\u2705 Saved {len(df)} events to {output_path}")

# %%
main()
# Out:
# [INFO] Found 225 filings
# [INFO] Parsing 10-Q from 2025-05-14
# [INFO] No valid events extracted from 2025-05-14, skipping.
# [INFO] Parsing 10-K from 2025-03-28
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2025-03-28, skipping.
# [INFO] Parsing 10-Q from 2024-11-13
# [INFO] No valid events extracted from 2024-11-13, skipping.
# [INFO] Parsing 8-K from 2024-09-17
# [INFO] Parsing 10-Q from 2024-08-13
# [INFO] Parsing 10-Q from 2024-05-14
# [INFO] Parsing 10-K from 2024-03-28
# [INFO] No valid events extracted from 2024-03-28, skipping.
# [INFO] Parsing 10-Q from 2023-11-13
# [INFO] Parsing 8-K from 2023-09-18
# [INFO] Parsing 10-Q from 2023-08-11
# [INFO] No valid events extracted from 2023-08-11, skipping.
# [INFO] Parsing 8-K from 2023-06-21
# [INFO] Parsing 10-Q from 2023-05-12
# [INFO] Parsing 10-K from 2023-03-30
# [INFO] No valid events extracted from 2023-03-30, skipping.
# [INFO] Parsing 8-K from 2023-03-16
# [INFO] Parsing 10-Q from 2022-11-14
# [INFO] No valid events extracted from 2022-11-14, skipping.
# [INFO] Parsing 8-K from 2022-09-16
# [INFO] Parsing 10-Q from 2022-08-12
# [INFO] Parsing 8-K from 2022-06-14
# [INFO] Parsing 10-Q from 2022-05-13
# [INFO] Parsing 8-K from 2022-04-29
# [INFO] Parsing 10-K from 2022-03-29
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2022-03-29, skipping.
# [INFO] Parsing 8-K from 2022-03-03
# [INFO] Parsing 8-K from 2022-02-02
# [INFO] Parsing 8-K from 2022-01-14
# [INFO] Parsing 8-K from 2021-12-28
# [INFO] Parsing 10-Q from 2021-11-12
# [INFO] No valid events extracted from 2021-11-12, skipping.
# [INFO] Parsing 8-K from 2021-11-01
# [INFO] Parsing 10-Q from 2021-08-13
# [INFO] No valid events extracted from 2021-08-13, skipping.
# [INFO] Parsing 8-K from 2021-06-30
# [INFO] Parsing 8-K from 2021-06-14
# [INFO] Parsing 10-Q from 2021-05-14
# [INFO] Parsing 10-K from 2021-03-30
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2021-03-30, skipping.
# [INFO] Parsing 8-K from 2021-03-08
# [INFO] Parsing 8-K from 2021-01-19
# [INFO] Parsing 10-Q from 2020-11-12
# [INFO] Parsing 10-Q from 2020-08-12
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2020-08-12, skipping.
# [INFO] Parsing 8-K from 2020-06-29
# [INFO] Parsing 10-Q from 2020-06-19
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2020-06-19, skipping.
# [INFO] Parsing 10-K from 2020-06-01
# [INFO] Parsing 8-K from 2020-05-13
# [INFO] Parsing 8-K from 2020-04-28
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2020-04-28, skipping.
# [INFO] Parsing 8-K from 2020-03-30
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2020-03-30, skipping.
# [INFO] Parsing 8-K from 2019-12-19
# [INFO] Parsing 10-Q from 2019-11-12
# [INFO] Parsing 10-Q from 2019-08-27
# [INFO] Parsing 8-K from 2019-07-30
# [INFO] Parsing 8-K from 2019-06-07
# [INFO] Parsing 10-Q from 2019-05-15
# [INFO] Parsing 8-K from 2019-04-23
# [INFO] Parsing 10-K from 2019-04-15
# [INFO] Parsing 8-K from 2019-01-23
# [INFO] Parsing 8-K from 2018-11-15
# [INFO] Parsing 10-Q from 2018-11-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2018-11-14, skipping.
# [INFO] Parsing 8-K from 2018-10-03
# [INFO] Parsing 10-Q from 2018-08-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2018-08-14, skipping.
# [INFO] Parsing 8-K from 2018-06-27
# [INFO] Parsing 8-K from 2018-06-05
# [INFO] Parsing 10-Q from 2018-05-21
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2018-05-21, skipping.
# [INFO] Parsing 8-K from 2018-05-16
# [INFO] Parsing 10-K from 2018-04-09
# [INFO] Parsing 8-K from 2018-03-08
# [INFO] Parsing 8-K from 2018-02-21
# [INFO] Parsing 8-K from 2017-12-13
# [INFO] Parsing 10-Q from 2017-11-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2017-11-14, skipping.
# [INFO] Parsing 8-K from 2017-09-06
# [INFO] Parsing 8-K from 2017-08-25
# [INFO] Parsing 10-Q from 2017-08-11
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2017-08-11, skipping.
# [INFO] Parsing 8-K from 2017-06-08
# [INFO] Parsing 8-K from 2017-06-06
# [INFO] Parsing 10-Q from 2017-05-15
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2017-05-15, skipping.
# [INFO] Parsing 10-K from 2017-03-31
# [INFO] Parsing 8-K from 2017-03-22
# [INFO] Parsing 8-K from 2017-02-28
# [INFO] Parsing 8-K from 2017-01-18
# [INFO] Parsing 8-K from 2016-12-13
# [INFO] Parsing 10-Q from 2016-11-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2016-11-14, skipping.
# [INFO] Parsing 8-K from 2016-09-19
# [INFO] Parsing 8-K from 2016-08-24
# [INFO] Parsing 10-Q from 2016-08-15
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2016-08-15, skipping.
# [INFO] Parsing 8-K from 2016-07-06
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2016-07-06, skipping.
# [INFO] Parsing 8-K from 2016-05-19
# [INFO] Parsing 10-Q from 2016-05-16
# [INFO] Parsing 10-K from 2016-03-30
# [INFO] Parsing 8-K from 2016-03-10
# [INFO] Parsing 8-K from 2016-03-10
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2016-03-10, skipping.
# [INFO] Parsing 8-K from 2016-03-03
# [INFO] Parsing 8-K from 2016-01-12
# [INFO] Parsing 8-K from 2015-12-15
# [INFO] Parsing 8-K from 2015-12-14
# [INFO] Parsing 8-K from 2015-12-04
# [INFO] Parsing 8-K from 2015-11-30
# [INFO] Parsing 10-Q from 2015-11-13
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2015-11-13, skipping.
# [INFO] Parsing 8-K from 2015-11-04
# [INFO] Parsing 8-K from 2015-10-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2015-10-14, skipping.
# [INFO] Parsing 8-K from 2015-10-13
# [INFO] Parsing 8-K from 2015-09-14
# [INFO] Parsing 8-K from 2015-09-09
# [INFO] Parsing 8-K from 2015-08-13
# [INFO] Parsing 10-Q from 2015-08-13
# [INFO] Parsing 8-K from 2015-08-11
# [INFO] Parsing 8-K from 2015-07-28
# [INFO] Parsing 8-K from 2015-06-05
# [INFO] Parsing 8-K from 2015-05-14
# [INFO] Parsing 10-Q from 2015-05-11
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2015-05-11, skipping.
# [INFO] Parsing 8-K from 2015-05-11
# [INFO] Parsing 8-K from 2015-05-08
# [INFO] Parsing 8-K from 2015-04-30
# [INFO] Parsing 8-K from 2015-04-23
# [INFO] Parsing 8-K from 2015-04-15
# [INFO] Parsing 8-K from 2015-04-01
# [INFO] Parsing 10-K from 2015-03-30
# [INFO] Parsing 8-K from 2015-03-23
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2015-03-23, skipping.
# [INFO] Parsing 8-K from 2015-01-07
# [INFO] Parsing 8-K from 2014-12-29
# [INFO] Parsing 8-K from 2014-12-05
# [INFO] Parsing 8-K from 2014-11-18
# [INFO] Parsing 10-Q from 2014-11-13
# [INFO] Parsing 8-K from 2014-11-13
# [INFO] Parsing 8-K from 2014-10-08
# [INFO] Parsing 8-K from 2014-09-16
# [INFO] Parsing 8-K from 2014-08-12
# [INFO] Parsing 8-K from 2014-08-11
# [INFO] Parsing 10-Q from 2014-08-08
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2014-08-08, skipping.
# [INFO] Parsing 8-K from 2014-07-01
# [INFO] Parsing 8-K from 2014-06-12
# [INFO] Parsing 8-K from 2014-06-04
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2014-06-04, skipping.
# [INFO] Parsing 8-K from 2014-05-14
# [INFO] Parsing 8-K from 2014-05-13
# [INFO] Parsing 10-Q from 2014-05-13
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2014-05-13, skipping.
# [INFO] Parsing 8-K from 2014-03-18
# [INFO] Parsing 10-K from 2014-03-17
# [INFO] Parsing 8-K from 2013-12-11
# [INFO] Parsing 8-K from 2013-11-13
# [INFO] Parsing 10-Q from 2013-11-13
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2013-11-13, skipping.
# [INFO] Parsing 8-K from 2013-09-19
# [INFO] Parsing 8-K from 2013-08-08
# [INFO] Parsing 10-Q from 2013-08-08
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2013-08-08, skipping.
# [INFO] Parsing 8-K from 2013-07-19
# [INFO] Parsing 8-K from 2013-06-13
# [INFO] Parsing 8-K from 2013-05-14
# [INFO] Parsing 10-Q from 2013-05-14
# [INFO] Parsing 8-K from 2013-04-15
# [INFO] Parsing 8-K from 2013-03-27
# [INFO] Parsing 10-K from 2013-03-26
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2013-03-26, skipping.
# [INFO] Parsing 8-K from 2013-03-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2013-03-14, skipping.
# [INFO] Parsing 8-K from 2013-02-14
# [INFO] Parsing 8-K from 2013-01-24
# [INFO] Parsing 8-K from 2012-12-05
# [INFO] Parsing 8-K from 2012-11-09
# [INFO] Parsing 10-Q from 2012-11-08
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2012-11-08, skipping.
# [INFO] Parsing 8-K from 2012-08-09
# [INFO] Parsing 10-Q from 2012-08-08
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2012-08-08, skipping.
# [INFO] Parsing 8-K from 2012-08-03
# [INFO] Parsing 8-K from 2012-06-04
# [INFO] Parsing 10-Q from 2012-05-14
# [INFO] Parsing 8-K from 2012-04-18
# [INFO] Parsing 8-K from 2012-03-28
# [INFO] Parsing 8-K from 2012-03-22
# [INFO] Parsing 10-K from 2012-03-16
# [INFO] Parsing 8-K from 2012-03-15
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2012-03-15, skipping.
# [INFO] Parsing 8-K from 2012-03-06
# [INFO] Parsing 8-K from 2012-01-18
# [INFO] Parsing 10-Q from 2011-11-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2011-11-14, skipping.
# [INFO] Parsing 8-K from 2011-10-12
# [INFO] Parsing 8-K from 2011-09-27
# [INFO] Parsing 10-Q from 2011-08-15
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2011-08-15, skipping.
# [INFO] Parsing 8-K from 2011-08-15
# [INFO] Parsing 10-Q from 2011-06-23
# [INFO] Parsing 8-K from 2011-05-31
# [INFO] Parsing 8-K from 2011-05-25
# [INFO] Parsing 8-K from 2011-05-13
# [INFO] Parsing 8-K from 2011-05-06
# [INFO] Parsing 8-K from 2011-03-29
# [INFO] Parsing 10-K from 2011-03-24
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2011-03-24, skipping.
# [INFO] Parsing 8-K from 2011-03-16
# [INFO] Parsing 8-K from 2011-02-28
# [INFO] Parsing 8-K from 2010-12-13
# [INFO] Parsing 10-Q from 2010-11-08
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2010-11-08, skipping.
# [INFO] Parsing 8-K from 2010-09-15
# [INFO] Parsing 10-Q from 2010-08-06
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2010-08-06, skipping.
# [INFO] Parsing 8-K from 2010-08-05
# [INFO] Parsing 8-K from 2010-06-22
# [INFO] Parsing 8-K from 2010-06-14
# [INFO] Parsing 8-K from 2010-05-19
# [INFO] Parsing 10-Q from 2010-05-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2010-05-14, skipping.
# [INFO] Parsing 8-K from 2010-05-05
# [INFO] Parsing 8-K from 2010-05-03
# [INFO] Parsing 10-K from 2010-03-23
# [INFO] Parsing 8-K from 2010-02-03
# [INFO] Parsing 10-Q from 2009-11-16
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2009-11-16, skipping.
# [INFO] Parsing 8-K from 2009-11-10
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2009-11-10, skipping.
# [INFO] Parsing 8-K from 2009-10-19
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2009-10-19, skipping.
# [INFO] Parsing 10-Q from 2009-08-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2009-08-14, skipping.
# [INFO] Parsing 8-K from 2009-07-06
# [INFO] Parsing 8-K from 2009-07-06
# [INFO] Parsing 10-Q from 2009-05-15
# [INFO] Parsing 10-K from 2009-03-30
# [INFO] Parsing 8-K from 2009-03-18
# [INFO] Parsing 8-K from 2009-02-06
# [INFO] Parsing 8-K from 2009-01-05
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2009-01-05, skipping.
# [INFO] Parsing 10-Q from 2008-11-13
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2008-11-13, skipping.
# [INFO] Parsing 8-K from 2008-10-16
# [INFO] Parsing 8-K from 2008-09-12
# [INFO] Parsing 8-K from 2008-08-21
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2008-08-21, skipping.
# [INFO] Parsing 8-K from 2008-08-18
# [INFO] Parsing 10-Q from 2008-08-14
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2008-08-14, skipping.
# [INFO] Parsing 8-K from 2008-07-31
# [INFO] Parsing 8-K from 2008-06-25
# [INFO] Parsing 8-K from 2008-06-09
# [INFO] Parsing 8-K from 2008-05-16
# [INFO] Parsing 10-Q from 2008-05-15
# [LLM ERROR] JSON parsing failed. Skipping this result.
# [INFO] No valid events extracted from 2008-05-15, skipping.
# [INFO] Parsing 8-K from 2008-05-12
# [INFO] Parsing 8-K from 2008-03-31
# [INFO] Parsing 8-K from 2008-01-22
# [INFO] Parsing 8-K from 2008-01-17
# [INFO] Parsing 8-K from 2008-01-14
# [INFO] Parsing 8-K from 2007-12-19
# [INFO] Parsing 8-K from 2007-09-06
# [INFO] Parsing 8-K from 2007-07-23
# [INFO] Parsing 8-K from 2007-06-28
# [INFO] Parsing 8-K from 2007-03-05
# [INFO] Parsing 8-K from 2006-12-29
# [INFO] Parsing 8-K from 2006-11-21
# [INFO] Parsing 8-K from 2006-11-08
# [INFO] Parsing 8-K from 2006-09-11
#
# ✅ Saved 542 events to /content/drive/MyDrive/SEC/isco_events_llm_V2.csv
